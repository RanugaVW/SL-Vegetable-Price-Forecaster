# %% [markdown]
# # Yala Season - Advanced XGBoost + LightGBM Ensemble Model
# This notebook trains an advanced ensemble model exclusively on the Yala season dataset.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import LabelEncoder
import os
import joblib
import optuna

def train_xgb_lgbm_advanced_yala():
    # Paths restricted to Yala
    data_path  = r'C:\Users\Ranuga\Data Science Project\5. Model Building\5.10 - Yala and Maha Seperation\Data\Yala_data.csv'
    output_dir = r'C:\Users\Ranuga\Data Science Project\5. Model Building\5.10 - Yala and Maha Seperation\Yala'
    model_dir  = os.path.join(output_dir, 'Models')
    report_dir = os.path.join(output_dir, 'Reports')
    os.makedirs(model_dir, exist_ok=True)
    os.makedirs(report_dir, exist_ok=True)

    # ───────────────────────────────────────────────────
    # 1. Load & Base Feature Engineering
    # ───────────────────────────────────────────────────
    print("Loading Yala data...")
    df = pd.read_csv(data_path)
    df.drop(columns=['code'], inplace=True, errors='ignore')

    df['week_num'] = pd.to_numeric(df['week'].str.extract(r'(\d+)')[0])
    df['week_sin'] = np.sin(2 * np.pi * df['week_num'] / 52)
    df['week_cos'] = np.cos(2 * np.pi * df['week_num'] / 52)

    regional_weather = (
        df.groupby(['Year_Week', 'vegetable_zone'])[['rain_sum', 'mean_apparent_temperature']]
        .mean().reset_index()
        .rename(columns={'rain_sum': 'reg_rain', 'mean_apparent_temperature': 'reg_temp'})
    )
    df = pd.merge(df, regional_weather, on=['Year_Week', 'vegetable_zone'], how='left')
    df.drop(columns=['Year_Week'], inplace=True, errors='ignore')

    df['season_enc'] = LabelEncoder().fit_transform(df['seasonality'].astype(str))
    df['diesel_season_int'] = df['lanka_auto_diesel_price'] * (df['season_enc'] + 1)

    df = df.sort_values(['retail_market', 'vegetable_type', 'year', 'week_num'])

    for col in ['retail_price', 'reg_rain', 'reg_temp']:
        for lag in [1, 2, 3, 4, 8]:
            df[f'{col}_lag_{lag}'] = df.groupby(['retail_market', 'vegetable_type'])[col].shift(lag)

    for lag in [1, 2, 3, 4, 5, 6, 8]:
        df[f'mean_farmer_price_lag_{lag}'] = df.groupby(['retail_market', 'vegetable_type'])['mean_farmer_price'].shift(lag)

    df['retail_price_roll_4'] = df.groupby(['retail_market', 'vegetable_type'])['retail_price'].transform(lambda x: x.shift(1).rolling(4).mean())

    grp = df.groupby(['retail_market', 'vegetable_type'])['mean_farmer_price']
    df['farmer_price_roll_4'] = grp.transform(lambda x: x.shift(1).rolling(4).mean())
    df['farmer_price_roll_8'] = grp.transform(lambda x: x.shift(1).rolling(8).mean())
    df['farmer_price_roll_std_4'] = grp.transform(lambda x: x.shift(1).rolling(4).std())
    df['farmer_price_pct_change_1'] = grp.transform(lambda x: x.shift(1).pct_change(1, fill_method=None))

    df['mean_farmer_price_filled'] = df['mean_farmer_price'].fillna(df['mean_farmer_price_lag_1'])
    df['farmer_retail_spread_lag_1'] = df['retail_price_lag_1'] - df['mean_farmer_price_lag_1']

    # ───────────────────────────────────────────────────
    # NEW: Advanced Momentum Features
    # ───────────────────────────────────────────────────
    # Price acceleration: is the price this week significantly higher than 4 weeks ago?
    df['retail_price_momentum_1_4'] = df['retail_price_lag_1'] / (df['retail_price_lag_4'] + 1e-5)
    df['farmer_price_momentum_1_4'] = df['mean_farmer_price_lag_1'] / (df['mean_farmer_price_lag_4'] + 1e-5)

    df_ready = df.dropna(subset=['retail_price_lag_8', 'mean_farmer_price_lag_8', 'farmer_price_roll_8', 'retail_price_momentum_1_4']).copy()

    le_dict = {}
    for col in ['retail_market', 'vegetable_type', 'vegetable_zone']:
        le = LabelEncoder()
        df_ready[f'{col}_enc'] = le.fit_transform(df_ready[col].astype(str))
        le_dict[col] = le

    # ───────────────────────────────────────────────────
    # 2. Train/Test Split
    # ───────────────────────────────────────────────────
    train_list, test_list = [], []
    for _, group in df_ready.groupby(['retail_market', 'vegetable_type']):
        split = int(len(group) * 0.8)
        train_list.append(group.iloc[:split])
        test_list.append(group.iloc[split:])

    train_df = pd.concat(train_list)
    test_df  = pd.concat(test_list)

    features = [
        'mean_farmer_price_filled', 'farmer_retail_spread_lag_1',
        'mean_farmer_price_lag_1', 'mean_farmer_price_lag_2',
        'mean_farmer_price_lag_3', 'mean_farmer_price_lag_4',
        'mean_farmer_price_lag_5', 'mean_farmer_price_lag_6',
        'mean_farmer_price_lag_8',
        'farmer_price_roll_4', 'farmer_price_roll_8',
        'farmer_price_roll_std_4', 'farmer_price_pct_change_1',
        'retail_price_momentum_1_4', 'farmer_price_momentum_1_4',
        'year', 'week_sin', 'week_cos',
        'lanka_auto_diesel_price', 'usd_exchange_rate', 'diesel_season_int',
        'no_of_holidays',
        'reg_rain', 'reg_temp',
        'retail_price_lag_1', 'retail_price_lag_2',
        'retail_price_lag_3', 'retail_price_lag_4', 'retail_price_lag_8',
        'reg_rain_lag_1', 'reg_rain_lag_4', 'reg_rain_lag_8',
        'reg_temp_lag_1', 'reg_temp_lag_4', 'reg_temp_lag_8',
        'retail_price_roll_4',
        'retail_market_enc', 'vegetable_type_enc', 'vegetable_zone_enc', 'season_enc'
    ]

    X_train, y_train = train_df[features], train_df['retail_price']
    X_test,  y_test  = test_df[features],  test_df['retail_price']
    
    # ───────────────────────────────────────────────────
    # NEW: Log Transformation on Target
    # ───────────────────────────────────────────────────
    y_train_log = np.log1p(y_train)
    y_test_log = np.log1p(y_test)

    # ───────────────────────────────────────────────────
    # 3. Expanded XGBoost Tuning (20 Trials)
    # ───────────────────────────────────────────────────
    print("\n--- Tuning XGBoost (20 Trials) ---")
    def objective_xgb(trial):
        param = {
            'n_estimators': trial.suggest_int('n_estimators', 300, 1000),
            'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
            'max_depth': trial.suggest_int('max_depth', 4, 12),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
            'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
            'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
            'random_state': 42
        }
        model = xgb.XGBRegressor(**param)
        model.fit(X_train, y_train_log, verbose=False)
        
        preds_log = model.predict(X_test)
        preds_raw = np.expm1(preds_log)
        
        return mean_absolute_percentage_error(y_test, preds_raw)

    study_xgb = optuna.create_study(direction='minimize')
    study_xgb.optimize(objective_xgb, n_trials=20)
    print(f"Best XGBoost Params (MAPE: {study_xgb.best_value:.4f}):", study_xgb.best_params)

    # ───────────────────────────────────────────────────
    # 4. Expanded LightGBM Tuning (20 Trials)
    # ───────────────────────────────────────────────────
    print("\n--- Tuning LightGBM (20 Trials) ---")
    def objective_lgb(trial):
        param = {
            'n_estimators': trial.suggest_int('n_estimators', 300, 1000),
            'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
            'max_depth': trial.suggest_int('max_depth', 4, 12),
            'num_leaves': trial.suggest_int('num_leaves', 20, 150),
            'subsample': trial.suggest_float('subsample', 0.5, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 50),
            'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
            'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
            'random_state': 42,
            'verbose': -1
        }
        model = lgb.LGBMRegressor(**param)
        model.fit(X_train, y_train_log)
        
        preds_log = model.predict(X_test)
        preds_raw = np.expm1(preds_log)
        
        return mean_absolute_percentage_error(y_test, preds_raw)

    study_lgb = optuna.create_study(direction='minimize')
    study_lgb.optimize(objective_lgb, n_trials=20)
    print(f"Best LightGBM Params (MAPE: {study_lgb.best_value:.4f}):", study_lgb.best_params)

    # ───────────────────────────────────────────────────
    # 5. Train Final Base Models
    # ───────────────────────────────────────────────────
    print("\nTraining Final Tuned Models...")
    final_xgb = xgb.XGBRegressor(**study_xgb.best_params, random_state=42)
    final_xgb.fit(X_train, y_train_log)
    
    lgb_params = study_lgb.best_params.copy()
    lgb_params['random_state'] = 42
    lgb_params['verbose'] = -1
    final_lgb = lgb.LGBMRegressor(**lgb_params)
    final_lgb.fit(X_train, y_train_log)

    pred_xgb_log = final_xgb.predict(X_test)
    pred_lgb_log = final_lgb.predict(X_test)
    
    pred_xgb_raw = np.expm1(pred_xgb_log)
    pred_lgb_raw = np.expm1(pred_lgb_log)

    # ───────────────────────────────────────────────────
    # 6. Optuna Ensemble Weight Tuning
    # ───────────────────────────────────────────────────
    print("\n--- Tuning Ensemble Weights ---")
    def objective_weight(trial):
        w_xgb = trial.suggest_float('w_xgb', 0.0, 1.0)
        w_lgb = 1.0 - w_xgb
        blended_preds = (w_xgb * pred_xgb_raw) + (w_lgb * pred_lgb_raw)
        return mean_absolute_percentage_error(y_test, blended_preds)

    study_weights = optuna.create_study(direction='minimize')
    study_weights.optimize(objective_weight, n_trials=30)
    
    optimal_w_xgb = study_weights.best_params['w_xgb']
    optimal_w_lgb = 1.0 - optimal_w_xgb
    print(f"Optimal Ensemble Weight found -> XGBoost: {optimal_w_xgb:.3f}, LightGBM: {optimal_w_lgb:.3f}")

    final_pred = (optimal_w_xgb * pred_xgb_raw) + (optimal_w_lgb * pred_lgb_raw)

    # ───────────────────────────────────────────────────
    # 7. Evaluation & Reporting
    # ───────────────────────────────────────────────────
    r2        = r2_score(y_test, final_pred)
    mape      = mean_absolute_percentage_error(y_test, final_pred)
    mape_xgb  = mean_absolute_percentage_error(y_test, pred_xgb_raw)
    mape_lgb  = mean_absolute_percentage_error(y_test, pred_lgb_raw)

    dataset_name = os.path.basename(data_path)
    report = f"""Yala Season - Advanced XGBoost + LightGBM Ensemble - DEEP OPTUNA TUNED
===========================================================
Model built from: {dataset_name} 
Target  : np.log1p(retail_price) -> Expm1 inverted logic
Optuna Trials: 20 per algorithm + 30 for Weight blending

Tuned Hyperparameters
--------------------
  XGBoost  : {study_xgb.best_params}
  LightGBM : {study_lgb.best_params}

Ensemble Blending
-----------------
  XGBoost Weight : {optimal_w_xgb:.4f}
  LightGBM Weight: {optimal_w_lgb:.4f}

Overall Ensemble Metrics
------------------------
  R2  Score              : {r2:.4f}
  Accuracy (1 - MAPE)    : {(1 - mape)*100:.2f}%
  MAPE                   : {mape*100:.2f}%

Individual Accuracies
---------------------
  XGBoost Accuracy       : {(1 - mape_xgb)*100:.2f}%
  LightGBM Accuracy      : {(1 - mape_lgb)*100:.2f}%
"""
    print(report)

    report_name = os.path.join(report_dir, 'yala_xgb_lgbm_advanced_ensemble_optuna_performance.txt')
    with open(report_name, 'w', encoding='utf-8') as f:
        f.write(report)

    bundle = {
        'xgb'            : final_xgb,
        'lgb'            : final_lgb,
        'features'       : features,
        'label_encoders' : le_dict,
        'weights'        : {'xgb': optimal_w_xgb, 'lgb': optimal_w_lgb},
        'target_transform': 'log1p'
    }
    model_name = os.path.join(model_dir, 'yala_xgb_lgbm_advanced_ensemble_optuna_model.joblib')
    joblib.dump(bundle, model_name)
    print(f"Artifacts saved explicitly to: {model_dir}")

    # ───────────────────────────────────────────────────
    # 8. Visualizing Actual vs Predicted (Line Charts)
    # ───────────────────────────────────────────────────
    import matplotlib.pyplot as plt
    
    print("\nGenerating Actual vs Predicted Line Charts...")
    test_df['predicted_price'] = final_pred
    
    # Pick the most prominent market in the test set to visualize
    sample_market = test_df['retail_market'].mode()[0]
    sample_vegs = test_df['vegetable_type'].unique()[:4]
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    fig.suptitle(f'Yala Season: Actual vs Predicted Prices in {sample_market}', fontsize=16)
    
    for ax, veg in zip(axes.flatten(), sample_vegs):
        subset = test_df[(test_df['retail_market'] == sample_market) & (test_df['vegetable_type'] == veg)]
        if not subset.empty:
            # Create a simple string for the X-axis (Year-Week)
            x_labels = subset['year'].astype(str) + "-W" + subset['week_num'].astype(str)
            
            ax.plot(x_labels, subset['retail_price'], label='Actual Valid Price', color='blue', marker='o', alpha=0.7)
            ax.plot(x_labels, subset['predicted_price'], label='Predicted Price', color='red', marker='x', alpha=0.7)
            ax.set_title(f"{veg}")
            ax.set_ylabel("Price (LKR)")
            
            # Show only a few x-ticks to prevent overlapping
            tick_spacing = max(1, len(x_labels) // 6)
            ax.set_xticks(np.arange(0, len(x_labels), tick_spacing))
            ax.tick_params(axis='x', rotation=45)
            ax.legend()
            ax.grid(True, linestyle='--', alpha=0.5)
            
    plot_path = os.path.join(report_dir, 'yala_actual_vs_predicted.png')
    plt.tight_layout()
    plt.savefig(plot_path)
    plt.show()

# %%
if __name__ == "__main__":
    train_xgb_lgbm_advanced_yala()
# Out:
# Loading Yala data...
# [I 2026-03-19 14:36:28,710] A new study created in memory with name: no-name-ccbd2b56-9f30-4f74-9479-0927d8f3ac76
# --- Tuning XGBoost (20 Trials) ---
# [I 2026-03-19 14:36:37,104] Trial 0 finished with value: 0.10342233644900714 and parameters: {'n_estimators': 866, 'learning_rate': 0.020390368897491337, 'max_depth': 7, 'subsample': 0.5739481521863197, 'colsample_bytree': 0.8777413444167252, 'min_child_weight': 9, 'reg_alpha': 0.0011145762871785172, 'reg_lambda': 0.022310874194623166}. Best is trial 0 with value: 0.10342233644900714.
# [I 2026-03-19 14:36:41,546] Trial 1 finished with value: 0.11926923752195852 and parameters: {'n_estimators': 627, 'learning_rate': 0.049056338438481055, 'max_depth': 6, 'subsample': 0.7255558058205969, 'colsample_bytree': 0.8839532707019325, 'min_child_weight': 4, 'reg_alpha': 8.467781976977386e-05, 'reg_lambda': 0.0696179707975588}. Best is trial 0 with value: 0.10342233644900714.
# [I 2026-03-19 14:36:45,145] Trial 2 finished with value: 0.09732236201092263 and parameters: {'n_estimators': 645, 'learning_rate': 0.0077990570054522965, 'max_depth': 5, 'subsample': 0.7052265927085384, 'colsample_bytree': 0.6119086488206364, 'min_child_weight': 10, 'reg_alpha': 2.1401667204211714e-05, 'reg_lambda': 0.02591830414071282}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:36:47,988] Trial 3 finished with value: 0.09918904534206605 and parameters: {'n_estimators': 702, 'learning_rate': 0.015410195515327275, 'max_depth': 4, 'subsample': 0.787295733717455, 'colsample_bytree': 0.8322939429936228, 'min_child_weight': 3, 'reg_alpha': 0.003507242355113929, 'reg_lambda': 0.04152453292310781}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:37:05,896] Trial 4 finished with value: 0.10105925675470327 and parameters: {'n_estimators': 760, 'learning_rate': 0.012409220848126873, 'max_depth': 11, 'subsample': 0.7506274045444543, 'colsample_bytree': 0.5464941200223147, 'min_child_weight': 6, 'reg_alpha': 8.669087166245794e-08, 'reg_lambda': 1.2339379122018687e-05}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:37:09,054] Trial 5 finished with value: 0.1007825352108931 and parameters: {'n_estimators': 818, 'learning_rate': 0.015391649193334692, 'max_depth': 4, 'subsample': 0.5906826567898852, 'colsample_bytree': 0.7847145613646798, 'min_child_weight': 4, 'reg_alpha': 4.471554902290709e-06, 'reg_lambda': 0.0006055994798446158}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:37:18,805] Trial 6 finished with value: 0.1035414531178782 and parameters: {'n_estimators': 444, 'learning_rate': 0.060712239770892094, 'max_depth': 12, 'subsample': 0.911755862030971, 'colsample_bytree': 0.9964235311510738, 'min_child_weight': 10, 'reg_alpha': 0.002234962405612117, 'reg_lambda': 0.008029424864875304}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:37:26,293] Trial 7 finished with value: 0.09873540400098758 and parameters: {'n_estimators': 435, 'learning_rate': 0.016890864443906636, 'max_depth': 8, 'subsample': 0.9487283904743036, 'colsample_bytree': 0.6621446581257577, 'min_child_weight': 3, 'reg_alpha': 0.17698442786121468, 'reg_lambda': 0.00024821904559238755}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:37:30,525] Trial 8 finished with value: 0.09896155511294276 and parameters: {'n_estimators': 583, 'learning_rate': 0.0070185455762239455, 'max_depth': 4, 'subsample': 0.5648791363838146, 'colsample_bytree': 0.9418455611563168, 'min_child_weight': 1, 'reg_alpha': 0.00011042701088259346, 'reg_lambda': 7.336779557344958e-06}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:37:39,822] Trial 9 finished with value: 0.09939027626649613 and parameters: {'n_estimators': 495, 'learning_rate': 0.03598718986904994, 'max_depth': 8, 'subsample': 0.5686509273979363, 'colsample_bytree': 0.9424036111252132, 'min_child_weight': 2, 'reg_alpha': 0.3589932817980948, 'reg_lambda': 4.68957944877702e-06}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:38:00,836] Trial 10 finished with value: 0.09844288703149595 and parameters: {'n_estimators': 988, 'learning_rate': 0.005224988470881423, 'max_depth': 10, 'subsample': 0.684033512194001, 'colsample_bytree': 0.6576298302165343, 'min_child_weight': 7, 'reg_alpha': 1.4096111218465872e-08, 'reg_lambda': 7.194069736836306}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:38:24,545] Trial 11 finished with value: 0.09813658752068383 and parameters: {'n_estimators': 1000, 'learning_rate': 0.005781029643376992, 'max_depth': 10, 'subsample': 0.6953854770437599, 'colsample_bytree': 0.661215838001241, 'min_child_weight': 7, 'reg_alpha': 1.0795254698871096e-08, 'reg_lambda': 6.645794028607376}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:38:42,473] Trial 12 finished with value: 0.09918601841224868 and parameters: {'n_estimators': 939, 'learning_rate': 0.008648061425362572, 'max_depth': 10, 'subsample': 0.8354881214100746, 'colsample_bytree': 0.5304246054106132, 'min_child_weight': 8, 'reg_alpha': 6.668255109631884e-07, 'reg_lambda': 8.764137835442956}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:38:46,301] Trial 13 finished with value: 0.1199822871344595 and parameters: {'n_estimators': 556, 'learning_rate': 0.09612740049226211, 'max_depth': 6, 'subsample': 0.6604606344912777, 'colsample_bytree': 0.6750556425868024, 'min_child_weight': 10, 'reg_alpha': 2.8084683993876892e-06, 'reg_lambda': 4.7352159505959236e-08}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:39:02,970] Trial 14 finished with value: 0.09972430748913062 and parameters: {'n_estimators': 689, 'learning_rate': 0.0050940293001416, 'max_depth': 10, 'subsample': 0.6602719404574481, 'colsample_bytree': 0.6117169949460897, 'min_child_weight': 8, 'reg_alpha': 1.2729182844867535e-07, 'reg_lambda': 0.6380385643881709}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:39:09,140] Trial 15 finished with value: 0.10045990039554281 and parameters: {'n_estimators': 302, 'learning_rate': 0.0094941583047984, 'max_depth': 9, 'subsample': 0.500197885359768, 'colsample_bytree': 0.7305356173214743, 'min_child_weight': 6, 'reg_alpha': 2.880387755019126e-05, 'reg_lambda': 0.5914982323785217}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:39:15,746] Trial 16 finished with value: 0.1167052139568955 and parameters: {'n_estimators': 870, 'learning_rate': 0.030479674016533027, 'max_depth': 6, 'subsample': 0.8460003915513414, 'colsample_bytree': 0.5808924513283257, 'min_child_weight': 8, 'reg_alpha': 1.49040573885646e-08, 'reg_lambda': 0.6845609487276368}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:39:46,169] Trial 17 finished with value: 0.10071919383446735 and parameters: {'n_estimators': 766, 'learning_rate': 0.007195003661238707, 'max_depth': 12, 'subsample': 0.9998551184256484, 'colsample_bytree': 0.5025791921514831, 'min_child_weight': 9, 'reg_alpha': 0.028422234977481045, 'reg_lambda': 0.00131402805243347}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:39:54,163] Trial 18 finished with value: 0.0980039758342057 and parameters: {'n_estimators': 343, 'learning_rate': 0.010732049489374847, 'max_depth': 9, 'subsample': 0.715267314084493, 'colsample_bytree': 0.7258312272653461, 'min_child_weight': 5, 'reg_alpha': 1.3256320365123949e-05, 'reg_lambda': 0.250780744162449}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:39:56,285] Trial 19 finished with value: 0.09918536804150353 and parameters: {'n_estimators': 312, 'learning_rate': 0.010948521173910021, 'max_depth': 5, 'subsample': 0.7783489517452784, 'colsample_bytree': 0.7360640178316084, 'min_child_weight': 5, 'reg_alpha': 1.1219946361380712e-05, 'reg_lambda': 8.067404228549875e-05}. Best is trial 2 with value: 0.09732236201092263.
# [I 2026-03-19 14:39:56,287] A new study created in memory with name: no-name-9a1d791f-8a5c-43a8-979f-a29b703d4f2e
# Best XGBoost Params (MAPE: 0.0973): {'n_estimators': 645, 'learning_rate': 0.0077990570054522965, 'max_depth': 5, 'subsample': 0.7052265927085384, 'colsample_bytree': 0.6119086488206364, 'min_child_weight': 10, 'reg_alpha': 2.1401667204211714e-05, 'reg_lambda': 0.02591830414071282}
#
# --- Tuning LightGBM (20 Trials) ---
# [I 2026-03-19 14:40:12,600] Trial 0 finished with value: 0.09975183088961949 and parameters: {'n_estimators': 740, 'learning_rate': 0.01692315138581709, 'max_depth': 10, 'num_leaves': 86, 'subsample': 0.9823657004669599, 'colsample_bytree': 0.7555280416415049, 'min_child_samples': 10, 'reg_alpha': 1.7781202779335633e-07, 'reg_lambda': 0.02497734793366188}. Best is trial 0 with value: 0.09975183088961949.
# [I 2026-03-19 14:40:14,544] Trial 1 finished with value: 0.10535967439743654 and parameters: {'n_estimators': 604, 'learning_rate': 0.09951482186952455, 'max_depth': 5, 'num_leaves': 75, 'subsample': 0.5130996565304737, 'colsample_bytree': 0.6616099559907851, 'min_child_samples': 39, 'reg_alpha': 1.169613390858903e-06, 'reg_lambda': 0.07954409103697951}. Best is trial 0 with value: 0.09975183088961949.
# [I 2026-03-19 14:40:17,709] Trial 2 finished with value: 0.10717218693622324 and parameters: {'n_estimators': 662, 'learning_rate': 0.06739785909719057, 'max_depth': 6, 'num_leaves': 148, 'subsample': 0.9651692152546387, 'colsample_bytree': 0.5742232202477724, 'min_child_samples': 18, 'reg_alpha': 6.933545354321858e-08, 'reg_lambda': 2.101039267019211e-06}. Best is trial 0 with value: 0.09975183088961949.
# [I 2026-03-19 14:40:21,817] Trial 3 finished with value: 0.09713610097522236 and parameters: {'n_estimators': 820, 'learning_rate': 0.007822714538694724, 'max_depth': 5, 'num_leaves': 97, 'subsample': 0.6652424237643052, 'colsample_bytree': 0.8233154170036445, 'min_child_samples': 9, 'reg_alpha': 0.0019111773763043308, 'reg_lambda': 2.2466403726752676e-07}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:40:27,962] Trial 4 finished with value: 0.1010388881372798 and parameters: {'n_estimators': 974, 'learning_rate': 0.06899206680541219, 'max_depth': 7, 'num_leaves': 134, 'subsample': 0.6550942210697084, 'colsample_bytree': 0.7249766320004322, 'min_child_samples': 25, 'reg_alpha': 2.2189134429191047e-07, 'reg_lambda': 0.026314067862389136}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:40:37,136] Trial 5 finished with value: 0.09784662761232182 and parameters: {'n_estimators': 863, 'learning_rate': 0.013080905560651382, 'max_depth': 8, 'num_leaves': 118, 'subsample': 0.5887797417246485, 'colsample_bytree': 0.6838115034703156, 'min_child_samples': 33, 'reg_alpha': 0.0011591250364509024, 'reg_lambda': 0.5477224312071961}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:40:43,551] Trial 6 finished with value: 0.09994165555964078 and parameters: {'n_estimators': 678, 'learning_rate': 0.03850878355285714, 'max_depth': 10, 'num_leaves': 137, 'subsample': 0.859740555222638, 'colsample_bytree': 0.684970142258051, 'min_child_samples': 48, 'reg_alpha': 5.8250679887853527e-08, 'reg_lambda': 0.0006214981492780514}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:40:56,787] Trial 7 finished with value: 0.10166134915500023 and parameters: {'n_estimators': 988, 'learning_rate': 0.05409231759642575, 'max_depth': 10, 'num_leaves': 96, 'subsample': 0.545959920295123, 'colsample_bytree': 0.7101317019339471, 'min_child_samples': 20, 'reg_alpha': 0.25110784177679507, 'reg_lambda': 1.4718233939350704e-08}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:41:02,504] Trial 8 finished with value: 0.09813743821777177 and parameters: {'n_estimators': 486, 'learning_rate': 0.014517101959740352, 'max_depth': 8, 'num_leaves': 96, 'subsample': 0.8422972211421356, 'colsample_bytree': 0.8652113601954072, 'min_child_samples': 47, 'reg_alpha': 0.011459194273585556, 'reg_lambda': 3.70269859101159e-08}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:41:08,603] Trial 9 finished with value: 0.09917367907490662 and parameters: {'n_estimators': 593, 'learning_rate': 0.02334703510407871, 'max_depth': 9, 'num_leaves': 97, 'subsample': 0.7090428779069915, 'colsample_bytree': 0.7229354023748477, 'min_child_samples': 21, 'reg_alpha': 9.635435460315507e-07, 'reg_lambda': 2.8352556389152882e-05}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:41:11,031] Trial 10 finished with value: 0.09894302753588217 and parameters: {'n_estimators': 825, 'learning_rate': 0.005683059139299918, 'max_depth': 4, 'num_leaves': 30, 'subsample': 0.7980172734858089, 'colsample_bytree': 0.9946779161024131, 'min_child_samples': 5, 'reg_alpha': 5.43352445268157e-05, 'reg_lambda': 1.4860456766696557e-06}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:41:25,278] Trial 11 finished with value: 0.09745644626772564 and parameters: {'n_estimators': 847, 'learning_rate': 0.007186607086967105, 'max_depth': 12, 'num_leaves': 120, 'subsample': 0.6241155243355804, 'colsample_bytree': 0.8401146218134787, 'min_child_samples': 35, 'reg_alpha': 0.0009179650751452985, 'reg_lambda': 6.587322106178856}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:41:28,412] Trial 12 finished with value: 0.11899631932195841 and parameters: {'n_estimators': 332, 'learning_rate': 0.0050661299574162625, 'max_depth': 12, 'num_leaves': 56, 'subsample': 0.6444671472675715, 'colsample_bytree': 0.8535630766680643, 'min_child_samples': 33, 'reg_alpha': 9.361059832714489e-05, 'reg_lambda': 3.1270333895036226}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:41:42,173] Trial 13 finished with value: 0.09852142812596315 and parameters: {'n_estimators': 859, 'learning_rate': 0.008623621153127618, 'max_depth': 12, 'num_leaves': 118, 'subsample': 0.7182754962246934, 'colsample_bytree': 0.8577431820518037, 'min_child_samples': 39, 'reg_alpha': 0.0031970481690349177, 'reg_lambda': 0.0003658619585217164}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:41:44,550] Trial 14 finished with value: 0.09768209161698661 and parameters: {'n_estimators': 765, 'learning_rate': 0.008325169804492358, 'max_depth': 4, 'num_leaves': 66, 'subsample': 0.6191661473009727, 'colsample_bytree': 0.9311876699512809, 'min_child_samples': 14, 'reg_alpha': 0.2038600024274322, 'reg_lambda': 7.631951877312087e-07}. Best is trial 3 with value: 0.09713610097522236.
# [I 2026-03-19 14:41:50,545] Trial 15 finished with value: 0.09648717839067866 and parameters: {'n_estimators': 921, 'learning_rate': 0.008423803637498008, 'max_depth': 6, 'num_leaves': 118, 'subsample': 0.6950068783988083, 'colsample_bytree': 0.801994483853516, 'min_child_samples': 29, 'reg_alpha': 2.0223662430704643e-05, 'reg_lambda': 0.0036204913480683072}. Best is trial 15 with value: 0.09648717839067866.
# [I 2026-03-19 14:41:56,537] Trial 16 finished with value: 0.09708618511305654 and parameters: {'n_estimators': 934, 'learning_rate': 0.011261124786215854, 'max_depth': 6, 'num_leaves': 107, 'subsample': 0.7581770394184462, 'colsample_bytree': 0.7850185711273736, 'min_child_samples': 27, 'reg_alpha': 1.3078440982582659e-05, 'reg_lambda': 0.002596080241741787}. Best is trial 15 with value: 0.09648717839067866.
# [I 2026-03-19 14:42:01,771] Trial 17 finished with value: 0.0971569748610085 and parameters: {'n_estimators': 915, 'learning_rate': 0.011186830196739014, 'max_depth': 6, 'num_leaves': 113, 'subsample': 0.7683223005369695, 'colsample_bytree': 0.6091197834179, 'min_child_samples': 26, 'reg_alpha': 8.0347022057621e-06, 'reg_lambda': 0.0040234508267600515}. Best is trial 15 with value: 0.09648717839067866.
# [I 2026-03-19 14:42:06,561] Trial 18 finished with value: 0.09879253868685275 and parameters: {'n_estimators': 940, 'learning_rate': 0.023725994798682603, 'max_depth': 7, 'num_leaves': 51, 'subsample': 0.9038468232220599, 'colsample_bytree': 0.5143590316030566, 'min_child_samples': 29, 'reg_alpha': 1.1191522082627173e-05, 'reg_lambda': 3.141127161767075e-05}. Best is trial 15 with value: 0.09648717839067866.
# [I 2026-03-19 14:42:09,920] Trial 19 finished with value: 0.09731730843260895 and parameters: {'n_estimators': 498, 'learning_rate': 0.017339007567865966, 'max_depth': 6, 'num_leaves': 132, 'subsample': 0.7358929248952477, 'colsample_bytree': 0.7836481724404466, 'min_child_samples': 41, 'reg_alpha': 1.1309537180348772e-08, 'reg_lambda': 0.002119710724137221}. Best is trial 15 with value: 0.09648717839067866.
# Best LightGBM Params (MAPE: 0.0965): {'n_estimators': 921, 'learning_rate': 0.008423803637498008, 'max_depth': 6, 'num_leaves': 118, 'subsample': 0.6950068783988083, 'colsample_bytree': 0.801994483853516, 'min_child_samples': 29, 'reg_alpha': 2.0223662430704643e-05, 'reg_lambda': 0.0036204913480683072}
#
# Training Final Tuned Models...
# [I 2026-03-19 14:42:19,019] A new study created in memory with name: no-name-6cf1fcfc-47c5-4894-9488-cd753b4d7831
# [I 2026-03-19 14:42:19,024] Trial 0 finished with value: 0.09615702884835127 and parameters: {'w_xgb': 0.457223508252499}. Best is trial 0 with value: 0.09615702884835127.
# [I 2026-03-19 14:42:19,025] Trial 1 finished with value: 0.09649551520180216 and parameters: {'w_xgb': 0.7115377281772165}. Best is trial 0 with value: 0.09615702884835127.
# [I 2026-03-19 14:42:19,026] Trial 2 finished with value: 0.09630299572952368 and parameters: {'w_xgb': 0.6025223363134857}. Best is trial 0 with value: 0.09615702884835127.
# [I 2026-03-19 14:42:19,029] Trial 3 finished with value: 0.09636880976453346 and parameters: {'w_xgb': 0.643893257583158}. Best is trial 0 with value: 0.09615702884835127.
# [I 2026-03-19 14:42:19,032] Trial 4 finished with value: 0.0963436864581725 and parameters: {'w_xgb': 0.6289654960566385}. Best is trial 0 with value: 0.09615702884835127.
# [I 2026-03-19 14:42:19,034] Trial 5 finished with value: 0.09612624461858273 and parameters: {'w_xgb': 0.3752670077119492}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,037] Trial 6 finished with value: 0.09612804656768877 and parameters: {'w_xgb': 0.31731504236619146}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,039] Trial 7 finished with value: 0.09638670713078328 and parameters: {'w_xgb': 0.05429538323259753}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,042] Trial 8 finished with value: 0.0961631354694643 and parameters: {'w_xgb': 0.46699612969641047}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,043] Trial 9 finished with value: 0.09612849234692733 and parameters: {'w_xgb': 0.3874274598295584}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,047] Trial 10 finished with value: 0.0972879058737565 and parameters: {'w_xgb': 0.9905898814048284}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,054] Trial 11 finished with value: 0.09618724454303215 and parameters: {'w_xgb': 0.205584384898496}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,057] Trial 12 finished with value: 0.09615665098373856 and parameters: {'w_xgb': 0.24578342877953588}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,062] Trial 13 finished with value: 0.09613253638609555 and parameters: {'w_xgb': 0.29703987275866667}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,067] Trial 14 finished with value: 0.0964801946040618 and parameters: {'w_xgb': 0.0035627306613294496}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,073] Trial 15 finished with value: 0.09620909252383356 and parameters: {'w_xgb': 0.18347107803167234}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,078] Trial 16 finished with value: 0.0967539653923046 and parameters: {'w_xgb': 0.821915928002458}. Best is trial 5 with value: 0.09612624461858273.
# [I 2026-03-19 14:42:19,084] Trial 17 finished with value: 0.09612469926875376 and parameters: {'w_xgb': 0.3530936839305787}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,088] Trial 18 finished with value: 0.09625559742004318 and parameters: {'w_xgb': 0.14287938400132344}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,093] Trial 19 finished with value: 0.09613147349025163 and parameters: {'w_xgb': 0.4004780475647055}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,097] Trial 20 finished with value: 0.09623383556303462 and parameters: {'w_xgb': 0.5497308732010562}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,101] Trial 21 finished with value: 0.09612660338112582 and parameters: {'w_xgb': 0.32582311724897467}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,107] Trial 22 finished with value: 0.09612470179542697 and parameters: {'w_xgb': 0.3532176918830085}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,113] Trial 23 finished with value: 0.09612910486521546 and parameters: {'w_xgb': 0.3902770404985919}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,117] Trial 24 finished with value: 0.0962004715483075 and parameters: {'w_xgb': 0.5160739674470702}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,124] Trial 25 finished with value: 0.09630457353088127 and parameters: {'w_xgb': 0.1050790816363289}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,130] Trial 26 finished with value: 0.0961486331922328 and parameters: {'w_xgb': 0.2595099898878417}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,135] Trial 27 finished with value: 0.09612562766561895 and parameters: {'w_xgb': 0.3687093639537967}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,141] Trial 28 finished with value: 0.09616156812582474 and parameters: {'w_xgb': 0.46451391888660376}. Best is trial 17 with value: 0.09612469926875376.
# [I 2026-03-19 14:42:19,148] Trial 29 finished with value: 0.09622635686258298 and parameters: {'w_xgb': 0.5426763969455053}. Best is trial 17 with value: 0.09612469926875376.
# --- Tuning Ensemble Weights ---
# Optimal Ensemble Weight found -> XGBoost: 0.353, LightGBM: 0.647
# Yala Season - Advanced XGBoost + LightGBM Ensemble - DEEP OPTUNA TUNED
# ===========================================================
# Model built from: Yala_data.csv
# Target  : np.log1p(retail_price) -> Expm1 inverted logic
# Optuna Trials: 20 per algorithm + 30 for Weight blending
#
# Tuned Hyperparameters
# --------------------
#   XGBoost  : {'n_estimators': 645, 'learning_rate': 0.0077990570054522965, 'max_depth': 5, 'subsample': 0.7052265927085384, 'colsample_bytree': 0.6119086488206364, 'min_child_weight': 10, 'reg_alpha': 2.1401667204211714e-05, 'reg_lambda': 0.02591830414071282}
#   LightGBM : {'n_estimators': 921, 'learning_rate': 0.008423803637498008, 'max_depth': 6, 'num_leaves': 118, 'subsample': 0.6950068783988083, 'colsample_bytree': 0.801994483853516, 'min_child_samples': 29, 'reg_alpha': 2.0223662430704643e-05, 'reg_lambda': 0.0036204913480683072}
#
# Ensemble Blending
# -----------------
#   XGBoost Weight : 0.3531
#   LightGBM Weight: 0.6469
#
# Overall Ensemble Metrics
# ------------------------
#   R2  Score              : 0.9420
#   Accuracy (1 - MAPE)    : 90.39%
#   MAPE                   : 9.61%
#
# Individual Accuracies
# ---------------------
#   XGBoost Accuracy       : 90.27%
#   LightGBM Accuracy      : 90.35%
#
# Artifacts saved explicitly to: C:\Users\Ranuga\Data Science Project\5. Model Building\5.10 - Yala and Maha Seperation\Yala\Models
#
# Generating Actual vs Predicted Line Charts...
