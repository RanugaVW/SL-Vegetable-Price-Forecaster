# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('final.csv')
df.head()
# Out:
#   Year_Week  year week retail_market  code vegetable_type  no_of_holidays  \
# 0   2013-w1  2013   w1  Anuradhapura   330  ASH PLANTAINS               0
# 1   2013-w2  2013   w2  Anuradhapura   330  ASH PLANTAINS               1
# 2   2013-w3  2013   w3  Anuradhapura   330  ASH PLANTAINS               0
# 3   2013-w4  2013   w4  Anuradhapura   330  ASH PLANTAINS               2
# 4   2013-w5  2013   w5  Anuradhapura   330  ASH PLANTAINS               1
#
#   vegetable_zone  seasonality  lanka_auto_diesel_price  \
# 0    LOW Country  Maha Season                    115.0
# 1    LOW Country  Maha Season                    115.0
# 2    LOW Country  Maha Season                    115.0
# 3    LOW Country  Maha Season                    115.0
# 4    LOW Country  Maha Season                    115.0
#
#    mean_apparent_temperature  rain_sum  usd_exchange_rate  mean_farmer_price  \
# 0                      28.57    120.14             127.07                NaN
# 1                      26.07      0.00             126.35                NaN
# 2                      26.93      7.62             126.74                NaN
# 3                      26.71      2.02             126.88                NaN
# 4                      28.39      6.98             126.31                NaN
#
#    retail_price  92
# 0          92.0 NaN
# 1          92.0 NaN
# 2          92.0 NaN
# 3          92.0 NaN
# 4          71.0 NaN
